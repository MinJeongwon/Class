# %% [markdown]
# # Mar 19, 2019
# # Mar 21, 2019
# ## Crawling
# 2018020143 민정원

# %% [markdown]
# # <네이버 뮤직 TOP10 가져오기>

# %% [markdown]
# ## STEP 1 > 필요한 라이브러리와 함수 가져오기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv

# %% [markdown]
# ## STEP 2 > 네이버 뮤직 홈 가져오기

# %%
html = urlopen('https://music.naver.com/home/index.nhn')
A = BeautifulSoup(html, "html.parser")
A
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>네이버 뮤직</title>
# <link href="/css/music.css?bv=20190322022158" rel="stylesheet" type="text/css"/>
# <link href="/css/music2.css?bv=20190322022158" rel="stylesheet" type="text/css"/>
# <script charset="utf-8" src="/js/pkg_jindo.all.js?bv=20190322022158" type="text/javascript"></script>
# <script charset="utf-8" src="/js/pkg_external.all.js?bv=20190322022158" type="text/javascript"></script>
# ...

# %% [markdown]
# ## STEP 3 > TOP 10부분 규칙 찾아보기

# %% [raw]
# <td class="name"><span class="m_ell"><a href="#" onclick="nhn.music.playMusic([26298196], null, 'play',[],[]);return false;">그건 아마 우리의 잘못은 아닐 거야</a></span></td>
# <td class="_artist artist"><span class="m_ell"><a class="_artist" href="#" onclick="nhn.music.moveUrl('/artist/home.nhn?artistId=234253');return false;">백예린</a></span></td>
# <td class="album"><span class="m_ell"><a class="_interest" href="#" onclick="nhn.music.moveUrl('/album/index.nhn?albumId=2938375');return false;">Our love is great</a></span></td>
#
#
#
# <td class="name"><span class="m_ell"><a href="#" onclick="nhn.music.playMusic([26357259], null, 'play',[],[]);return false;">당신과는 천천히</a></span></td>
# <td class="_artist artist"><span class="m_ell"><a class="_artist" href="#" onclick="nhn.music.moveUrl('/artist/home.nhn?artistId=170739');return false;">장범준</a></span></td>
# <td class="album"><span class="m_ell"><a class="_interest" href="#" onclick="nhn.music.moveUrl('/album/index.nhn?albumId=2946382');return false;">장범준 3집</a></span></td>
#
#
#
# <td class="name"><span class="m_ell"><a href="#" onclick="nhn.music.playMusic([25534507], null, 'play',[],[]);return false;">달라달라</a></span></td>
# <td class="_artist artist"><span class="m_ell"><a class="_artist" href="#" onclick="nhn.music.moveUrl('/artist/home.nhn?artistId=2708920');return false;">ITZY(있지)</a></span></td>
# <td class="album"><span class="m_ell"><a class="_interest" href="#" onclick="nhn.music.moveUrl('/album/index.nhn?albumId=2841538');return false;">IT'z Different</a></span></td>
#
#
#
# **td class="name"에 곡명, td class=_artist artist에 가수명, td class=album에 앨범명이 있는 것 확인**

# %% [markdown]
# ## STEP 4 > 사용할 함수 결정하기

# %% [markdown]
# ### 1. 곡명 : title

# %%
title = A.find("td", {"class" : "name"})
print(title.get_text())
# Out:
# 그건 아마 우리의 잘못은 아닐 거야

# %% [markdown]
# ### 2. 가수명 : artist

# %%
artist = A.find("td", {"class" : "_artist artist"})
print(artist.get_text())
# Out:
# 백예린

# %% [markdown]
# ### 3. 앨범명 : album

# %%
album = A.find("td", {"class" : "album"})
print(album.get_text())
# Out:
# Our love is great

# %% [markdown]
# ### 4. 시각 : time

# %%
time = A.find("span", {"class" : "dsc"})
A.find("span", {"class" : "dsc"}).get_text()
# Out:
# '2019년 03월 23일 오후-12시 차트입니다.'

# %% [markdown]
# ## STEP 5 > 함수 종합하여 1~10위까지 목록 만들기

# %%
for n in range(1,9):
    title = A.find("td", {"class" : "name"}).get_text()
    artist = A.find("td", {"class" : "_artist artist"}).get_text()
    album = A.find("td", {"class" : "album"}).get_text()
    time = A.find("span", {"class" : "dsc"}).get_text()
    print(n+1, title, artist, album)
# Out:
# 2 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 3 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 4 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 5 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 6 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 7 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 8 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great
# 9 그건 아마 우리의 잘못은 아닐 거야 백예린 Our love is great

# %%
# Create a file to write to, add headers row
with open('crawling.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['rank', 'title', 'author', 'publisher'])
        
    for n in range(0,25):
        dt = bsObject.find("dt", {"id":"book_title_"+str(n)})
        title = dt.select('a')[0].get_text()
        author = dt.next_sibling.next_sibling.select('a')[0].get_text()
        publisher = dt.next_sibling.next_sibling.get_text().split()[-1]
        print(n+1, title, author, publisher)
